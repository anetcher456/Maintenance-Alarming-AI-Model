# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_A = pd.read_csv("project_datasets/data_A.csv")
df_AA = pd.read_csv("project_datasets/data_AA.csv")
df_AB = pd.read_csv("project_datasets/data_AB.csv")
df_AC = pd.read_csv("project_datasets/data_AC.csv")
df_AD = pd.read_csv("project_datasets/data_AD.csv")
df_B = pd.read_csv("project_datasets/data_B.csv")
df_C = pd.read_csv("project_datasets/data_C.csv")
df_D = pd.read_csv("project_datasets/data_D.csv")
df_E = pd.read_csv("project_datasets/data_E.csv")
df_F = pd.read_csv("project_datasets/data_F.csv")
df_G = pd.read_csv("project_datasets/data_G.csv")
df_H = pd.read_csv("project_datasets/data_H.csv")
df_I = pd.read_csv("project_datasets/data_I.csv")
df_J = pd.read_csv("project_datasets/data_J.csv")
df_K = pd.read_csv("project_datasets/data_K.csv")
df_M = pd.read_csv("project_datasets/data_M.csv")
df_N = pd.read_csv("project_datasets/data_N.csv")
df_O = pd.read_csv("project_datasets/data_O.csv")
df_P = pd.read_csv("project_datasets/data_P.csv")
df_Q = pd.read_csv("project_datasets/data_Q.csv")
df_R = pd.read_csv("project_datasets/data_R.csv")
df_S = pd.read_csv("project_datasets/data_S.csv")
df_T = pd.read_csv("project_datasets/data_T.csv")
df_U = pd.read_csv("project_datasets/data_U.csv")
df_V = pd.read_csv("project_datasets/data_V.csv")
df_W = pd.read_csv("project_datasets/data_W.csv")
df_X = pd.read_csv("project_datasets/data_X.csv")
df_Y = pd.read_csv("project_datasets/data_Y.csv")
df_Z = pd.read_csv("project_datasets/data_Z.csv")

# %%
df_A.info()
df_AA.info()
df_AB.info()
df_AC.info()
df_AD.info()
df_B.info()
df_C.info()
df_D.info()
df_E.info()
df_F.info()
df_G.info()
df_H.info()
df_I.info()
df_J.info()
df_K.info()
df_M.info()
df_N.info()
df_O.info()
df_P.info()
df_Q.info()
df_R.info()
df_S.info()
df_T.info()
df_U.info()
df_V.info()
df_W.info()
df_X.info()
df_Y.info()
df_Z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312657 entries, 0 to 312656
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   DeviceId  312657 non-null  object
#  1   EventDt   312657 non-null  object
#  2   Temp      312657 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 7.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297482 entries, 0 to 297481
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   DeviceId  297482 non-null  object
#  1   EventDt   297482 non-null  object
#  2   Temp      297482 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 6.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530979 entries, 0 to 530978
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   DeviceId  530979 non-null  object
# ...

# %%
df_A.isna().sum()
# Out:
# DeviceId    0
# EventDt     0
# Temp        0
# dtype: int64

# %% [markdown]
# ## The datasets do not seem to be having any missing values (The data is complete)

# %%
df_test = pd.read_excel("project_datasets/data_A.xlsx")
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312657 entries, 0 to 312656
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   DeviceId  312657 non-null  object
#  1   EventDt   312657 non-null  datetime64[ns]
#  2   Temp      312657 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 7.2+ MB

# %% [markdown]
# ## The Modified datasets (Exported to CSV) do however read the EventDt as object and not as a datetime format. We should only use the CSV for testing because they load quickly

# %%
df_A = df_A.sample(1000)
df_A = df_A.sample(1000)
df_AA = df_AA.sample(1000)
df_AB = df_AB.sample(1000)
df_AC = df_AC.sample(1000)
df_AD = df_AD.sample(1000)
df_B = df_B.sample(1000)
df_C = df_C.sample(1000)
df_D = df_D.sample(1000)
df_E = df_E.sample(1000)
df_F = df_F.sample(1000)
df_G =df_G.sample(1000)
df_H =df_H.sample(1000)
df_I =df_I.sample(1000)
df_J =df_J.sample(1000)
df_K =df_K.sample(1000)
df_M =df_M.sample(1000)
df_N =df_N.sample(1000)
df_O =df_O.sample(1000)
df_P =df_P.sample(1000)
df_Q =df_Q.sample(1000)
df_R =df_R.sample(1000)
df_S =df_S.sample(1000)
df_T =df_T.sample(1000)
df_U =df_U.sample(1000)
df_V =df_V.sample(1000)
df_W =df_W.sample(1000)
df_X =df_X.sample(1000)
df_Y =df_Y.sample(1000)
df_Z =df_Z.sample(1000)

# We use .sample() to take a random sample from each dataframe instead of the whole dataset.
# Helps with loading SeaBorn Graphs

# %%
sns.relplot(x="EventDt", y="Temp",data=df_A,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_AA,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_AB,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_AC,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_AD,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_B,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_C,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_D,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_E,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_F,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_G,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_H,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_I,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_J,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_K,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_M,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_N,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_O,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_P,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_Q,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_R,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_S,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_T,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_U,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_V,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_W,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_X,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_Y,estimator=None, kind="line",ci="none")
sns.relplot(x="EventDt", y="Temp",data=df_Z,estimator=None, kind="line",ci="none")
# Out:
# C:\Users\CybiW\anaconda3\lib\site-packages\seaborn\axisgrid.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)

# %% [markdown]
# # Some datasets contain some "extreme" temperature changes ( from 30 to -20). We will have to look into that.

# %% [markdown]
# ## Some sensors have Lower and Upper Limit (AA,AC,B,E,F,G,H,I,K,M,N,R,S,V,W,X,Y,Z)

# %% [raw]
# ID | Lower | Upper Limit
# B	2	8
# E	-40	-18
# F	0	7
# G	-5	7
# H	-40	-8
# I	8	25
# K	0	-20
# M	2	8
# N	12	21
# R	0	7
# S	0	4
# V	2	8
# W	2	8
# X	2	8
# Y	-30	-3
# Z	2	8
# AA	-30	-18
# AC	36	62

# %% [markdown]
# # The prediction about sounding the alarm may or not only apply to the devices with Upper and Lower Limit
